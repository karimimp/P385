# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
r = 1
mean = [15, 5]
cov = [[1,r], [r,1]]

x,y = x, y=np.random.multivariate_normal(mean, cov, 400).T

plt.subplot(1,2,1)
plt.hist(x = x, bins=15)
plt.title("X")

plt.subplot(1,2,2)
plt.hist(x = y, bins=15)
plt.title("Y")
# Out:
# Text(0.5, 1.0, 'Y')

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,2)
plt.scatter(x=x, y=y)
plt.title("Joint Dist. of X and Y")

plt.subplot(2,2,1)
plt.hist(x = x, bins = 15)
plt.title("Marginal Dist. X")

plt.subplot(2,2,4)
plt.hist(x = y, orientation="horizontal", bins = 15)
plt.title("Marginal Dist. Y")
# Out:
# Text(0.5, 1.0, 'Marginal Dist. Y')
