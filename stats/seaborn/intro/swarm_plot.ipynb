# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
cars = sns.load_dataset('mpg').dropna()

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.swarmplot(x=cars.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.swarmplot(x=cars.origin, y=cars.horsepower)
# Out:
# /home/mohsen/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.swarmplot(x='origin', y='horsepower', hue='cylinders', data=cars)
# Out:
# /home/mohsen/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ## Overlay Swarmplot

# %%
usa = cars[cars.origin=='usa']

# %%
sns.boxplot(x=usa.cylinders, y=usa.horsepower, whis=np.inf)
sns.swarmplot(x=usa.cylinders, y=usa.horsepower, color='k', size=4, alpha=.5)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>
